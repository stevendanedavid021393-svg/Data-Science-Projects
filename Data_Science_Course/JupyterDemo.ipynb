# %% [markdown]
# # Jupyter Demo
# **Data Science Course — Create a Jupyter Notebook in Python Assignment**
#
# This notebook demonstrates how to import the Pandas library and display data in a DataFrame.

# %%
import pandas as pd  #notice we use 'pd'
                     #accessing the Pandas library

# %%
data = {
    'cats':[3,5,3,2],
    'dogs':[5,3,8,4]
}

# %%
listView = pd.DataFrame(data)  #notice we use 'pd'
                               #accessing the Pandas library

listView  #we can print a dataframe by simply typing its name
# Out:
#    cats  dogs
# 0     3     5
# 1     5     3
# 2     3     8
# 3     2     4
